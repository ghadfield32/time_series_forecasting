# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Step 1: Load and preprocess the dataset
def load_data(file_path, player_id=None, debug=False):
    """
    Load the dataset and filter it to only include the given player's data.
    Additional preprocessing includes filtering out 'Uncatchable' from 'catch_difficulty'.
    """
    league_df = pd.read_csv(file_path)
    
    # Remove "Uncatchable" entries
    league_df = league_df[league_df['catch_difficulty'] != 'Uncatchable']

    # Convert numeric columns to appropriate types
    numeric_columns = league_df.select_dtypes(include=['float64', 'int64']).columns
    league_df[numeric_columns] = league_df[numeric_columns].apply(pd.to_numeric, errors='coerce')
    
    # Filter for the given player
    player_df = league_df[league_df['cf_id'] == player_id] if player_id else None

    if debug:
        print("Loaded DataFrame Shape: ", league_df.shape)
        print("Filtered Player Data Shape: ", player_df.shape if player_df is not None else 'No Player Filter')
        print("Columns in Dataset: ", league_df.columns)
    
    return player_df, league_df

# Step 2: Calculate percentile ranks
def calculate_percentiles(df, metrics):
    percentiles_df = pd.DataFrame(index=df.index)
    for metric in metrics:
        percentiles_df[f'{metric}_Percentile'] = df[metric].rank(pct=True) * 100
    return percentiles_df

# Step 3: Compare player statistics to league averages
def compare_player_to_league(player_df, league_df, metrics, debug=False):
    player_avg = player_df[metrics].mean()
    league_avg = league_df[metrics].mean()
    
    comparison_df = pd.DataFrame({'Player Average': player_avg})
    comparison_df['League Average'] = league_avg
    comparison_df['Difference'] = comparison_df['Player Average'] - comparison_df['League Average']
    comparison_df['Percent Difference'] = ((comparison_df['Player Average'] - comparison_df['League Average']) / comparison_df['League Average']) * 100

    player_percentiles = calculate_percentiles(player_df, metrics).mean()
    league_percentiles = calculate_percentiles(league_df, metrics).mean()

    for metric in metrics:
        comparison_df[f'Player {metric} Percentile'] = player_percentiles[f'{metric}_Percentile']
        comparison_df[f'League {metric} Percentile'] = league_percentiles[f'{metric}_Percentile']

    if debug:
        print("Player vs League Comparison with Percentiles:\n", comparison_df)
    
    return comparison_df

# Step 4: Compare player performance within cluster
def compare_player_to_cluster(player_df, league_df, cluster_column='defensive_cluster_label', metrics=None, debug=False):
    player_cluster = player_df[cluster_column].iloc[0]
    cluster_df = league_df[league_df[cluster_column] == player_cluster]
    
    if not metrics:
        metrics = cluster_df.select_dtypes(include=np.number).columns.tolist()

    cluster_summary = cluster_df[metrics].mean().to_frame(name='Cluster Average')
    player_summary = player_df[metrics].mean().to_frame(name='Player Average')

    cluster_comparison_df = pd.merge(player_summary, cluster_summary, left_index=True, right_index=True)
    cluster_comparison_df['Difference'] = cluster_comparison_df['Player Average'] - cluster_comparison_df['Cluster Average']
    cluster_comparison_df['Percent Difference'] = ((cluster_comparison_df['Player Average'] - cluster_comparison_df['Cluster Average']) / cluster_comparison_df['Cluster Average']) * 100

    player_percentiles = calculate_percentiles(player_df, metrics).mean()
    cluster_percentiles = calculate_percentiles(cluster_df, metrics).mean()

    for metric in metrics:
        cluster_comparison_df[f'Player {metric} Percentile'] = player_percentiles[f'{metric}_Percentile']
        cluster_comparison_df[f'Cluster {metric} Percentile'] = cluster_percentiles[f'{metric}_Percentile']

    if debug:
        print("Player vs Cluster Comparison with Percentiles:\n", cluster_comparison_df)

    return cluster_comparison_df

# Step : Compare player performance under different conditions
def compare_player_under_conditions(player_df, league_df, condition_column, metrics):
    """
    Compare player statistics under different conditions, such as temperature, venue, pitch side, etc.
    """
    # Get unique conditions
    unique_conditions = league_df[condition_column].unique()
    comparison_results = {}

    for condition in unique_conditions:
        # Filter data based on the current condition
        player_condition_df = player_df[player_df[condition_column] == condition]
        league_condition_df = league_df[league_df[condition_column] == condition]

        # Calculate the comparison between the player and league under this condition
        if not player_condition_df.empty and not league_condition_df.empty:
            comparison_df = compare_player_to_league(player_condition_df, league_condition_df, metrics)
            comparison_results[condition] = comparison_df

    return comparison_results


# Step 5: Generate Top and Bottom Percentiles Report
def get_top_and_bottom_percentiles(df, metrics, top_n=5, bottom_n=5, cluster_filter=None, catch_difficulty_filter=None):
    if cluster_filter:
        if isinstance(cluster_filter, list):
            df = df[df['defensive_cluster_label'].isin(cluster_filter)]
        else:
            df = df[df['defensive_cluster_label'] == cluster_filter]

    if catch_difficulty_filter:
        if isinstance(catch_difficulty_filter, list):
            df = df[df['catch_difficulty'].isin(catch_difficulty_filter)]
        else:
            df = df[df['catch_difficulty'] == catch_difficulty_filter]

    top_players = {}
    bottom_players = {}

    for metric in metrics:
        if metric not in df.columns:
            print(f"Metric {metric} not found in the DataFrame. Skipping...")
            continue
        
        top_players[metric] = df.nlargest(top_n, metric)
        bottom_players[metric] = df.nsmallest(bottom_n, metric)

    top_df = pd.concat(top_players, axis=0)
    bottom_df = pd.concat(bottom_players, axis=0)

    return top_df, bottom_df

# Step 6: Generate Scouting Report with Condition-Based Comparisons
def generate_scouting_report(file_path, player_id, metrics=None, condition_columns=None, debug=False):
    if metrics is None:
        metrics = ['reaction_speed', 'distance_covered', 'catch_probability']

    player_data, league_data = load_data(file_path, player_id, debug)
    league_comparison = compare_player_to_league(player_data, league_data, metrics, debug)

    report = f"""
    **Scouting Report: Player ID {player_id}**
    
    **Player Overview**:
    This report focuses on evaluating the defensive performance of the player (ID: {player_id}) based on their clustering, league comparison, and advanced metrics. The key metrics used are {', '.join(metrics)}.

    **League Comparison Analysis**:
    Against the league average, the player's performance is:
    {league_comparison.to_string()}
    """

    if condition_columns:
        report += "\n\n**Condition-Based Performance Analysis**:\n"
        for condition in condition_columns:
            condition_comparison = compare_player_under_conditions(player_data, league_data, condition, metrics)

            for condition_value, comparison_df in condition_comparison.items():
                report += f"\n**Performance under {condition}: {condition_value}**\n"
                for metric in metrics:
                    report += f"- {metric.capitalize()}: Player Average: {comparison_df.loc[metric, 'Player Average']:.2f}, League Average: {comparison_df.loc[metric, 'League Average']:.2f}, Difference: {comparison_df.loc[metric, 'Difference']:.2f}, Percent Difference: {comparison_df.loc[metric, 'Percent Difference']:.2f}%\n"
                
    return report, league_comparison

# Example usage with specific conditions and automated metrics
file_path = "../../data/Seattle Mariners 2025 Analytics Internship/data-train-preprocessed.csv"
player_id = 15411
metrics_to_compare = ['reaction_speed', 'distance_covered', 'catch_probability']
condition_columns = ['temperature_category', 'bat_side', 'pitch_side', 'top', 'venue_id', 'count_scenario']

# Generate and display report
report, league_comparison = generate_scouting_report(file_path, player_id, metrics=metrics_to_compare, condition_columns=condition_columns, debug=True)
print(report)
# Out:
# Loaded DataFrame Shape:  (54854, 40)
# Filtered Player Data Shape:  (846, 40)
# Columns in Dataset:  Index(['pitch_id', 'level', 'bat_side', 'pitch_side', 'top', 'venue_id',
#        'lf_id', 'cf_id', 'rf_id', 'exit_speed', 'hit_spin_rate',
#        'vert_exit_angle', 'horz_exit_angle', 'first_fielder', 'is_airout',
#        'count_scenario', 'month', 'day_of_week', 'is_weekend',
#        'temperature_category', 'estimated_distance', 'landing_x', 'landing_y',
#        'adjusted_distance', 'landing_x_adjusted', 'landing_y_adjusted',
#        'hit_direction', 'is_home_run', 'is_catchable_home_run', 'is_foul',
#        'vert_angle_rad', 'hang_time', 'distance_covered', 'reaction_speed',
#        'catch_probability', 'catch_difficulty', 'fielder_position',
#        'defensive_cluster_kmeans', 'defensive_cluster_dbscan',
#        'defensive_cluster_label'],
#       dtype='object')
# Player vs League Comparison with Percentiles:
#                     Player Average  League Average  Difference  \
# reaction_speed          13.645221       13.427229    0.217992
# distance_covered        83.114090       82.382797    0.731293
# catch_probability        0.061491        0.058446    0.003045
#
#                    Percent Difference  Player reaction_speed Percentile  \
# reaction_speed               1.623508                         50.059102
# distance_covered             0.887677                         50.059102
# catch_probability            5.210184                         50.059102
#
#                    League reaction_speed Percentile  \
# reaction_speed                            50.000912
# distance_covered                          50.000912
# catch_probability                         50.000912
#
#                    Player distance_covered Percentile  \
# reaction_speed                              50.147929
# distance_covered                            50.147929
# catch_probability                           50.147929
#
#                    League distance_covered Percentile  \
# reaction_speed                              50.002232
# distance_covered                            50.002232
# catch_probability                           50.002232
#
#                    Player catch_probability Percentile  \
# reaction_speed                               50.147929
# distance_covered                             50.147929
# catch_probability                            50.147929
#
#                    League catch_probability Percentile
# reaction_speed                               50.002232
# distance_covered                             50.002232
# catch_probability                            50.002232
#
#     **Scouting Report: Player ID 15411**
#
#     **Player Overview**:
#     This report focuses on evaluating the defensive performance of the player (ID: 15411) based on their clustering, league comparison, and advanced metrics. The key metrics used are reaction_speed, distance_covered, catch_probability.
#
#     **League Comparison Analysis**:
#     Against the league average, the player's performance is:
#                        Player Average  League Average  Difference  Percent Difference  Player reaction_speed Percentile  League reaction_speed Percentile  Player distance_covered Percentile  League distance_covered Percentile  Player catch_probability Percentile  League catch_probability Percentile
# reaction_speed          13.645221       13.427229    0.217992            1.623508                         50.059102                         50.000912                           50.147929                           50.002232                            50.147929                            50.002232
# distance_covered        83.114090       82.382797    0.731293            0.887677                         50.059102                         50.000912                           50.147929                           50.002232                            50.147929                            50.002232
# catch_probability        0.061491        0.058446    0.003045            5.210184                         50.059102                         50.000912                           50.147929                           50.002232                            50.147929                            50.002232
#
#
# **Condition-Based Performance Analysis**:
#
# **Performance under temperature_category: Moderate**
# - Reaction_speed: Player Average: 14.19, League Average: 13.40, Difference: 0.79, Percent Difference: 5.89%
# - Distance_covered: Player Average: 82.46, League Average: 82.02, Difference: 0.44, Percent Difference: 0.54%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: -0.00, Percent Difference: -0.56%
#
# **Performance under temperature_category: Cold**
# - Reaction_speed: Player Average: 20.06, League Average: 13.72, Difference: 6.35, Percent Difference: 46.26%
# - Distance_covered: Player Average: 104.78, League Average: 83.52, Difference: 21.26, Percent Difference: 25.46%
# - Catch_probability: Player Average: 0.05, League Average: 0.06, Difference: -0.01, Percent Difference: -18.85%
#
# **Performance under temperature_category: Hot**
# - Reaction_speed: Player Average: 10.38, League Average: 13.08, Difference: -2.71, Percent Difference: -20.68%
# - Distance_covered: Player Average: 75.84, League Average: 82.46, Difference: -6.62, Percent Difference: -8.03%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.02, Percent Difference: 27.24%
#
# **Performance under bat_side: R**
# - Reaction_speed: Player Average: 14.07, League Average: 13.40, Difference: 0.66, Percent Difference: 4.93%
# - Distance_covered: Player Average: 83.67, League Average: 82.07, Difference: 1.60, Percent Difference: 1.95%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 3.95%
#
# **Performance under bat_side: L**
# - Reaction_speed: Player Average: 13.09, League Average: 13.46, Difference: -0.36, Percent Difference: -2.70%
# - Distance_covered: Player Average: 82.36, League Average: 82.78, Difference: -0.42, Percent Difference: -0.51%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 6.88%
#
# **Performance under pitch_side: R**
# - Reaction_speed: Player Average: 12.42, League Average: 13.34, Difference: -0.93, Percent Difference: -6.94%
# - Distance_covered: Player Average: 80.68, League Average: 82.09, Difference: -1.42, Percent Difference: -1.73%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 6.61%
#
# **Performance under pitch_side: L**
# - Reaction_speed: Player Average: 20.07, League Average: 13.76, Difference: 6.31, Percent Difference: 45.88%
# - Distance_covered: Player Average: 93.16, League Average: 83.48, Difference: 9.68, Percent Difference: 11.60%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: -0.00, Percent Difference: -0.61%
#
# **Performance under top: 0**
# - Reaction_speed: Player Average: 13.13, League Average: 13.22, Difference: -0.09, Percent Difference: -0.68%
# - Distance_covered: Player Average: 84.85, League Average: 82.27, Difference: 2.58, Percent Difference: 3.14%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.01, Percent Difference: 16.73%
#
# **Performance under top: 1**
# - Reaction_speed: Player Average: 14.15, League Average: 13.62, Difference: 0.53, Percent Difference: 3.88%
# - Distance_covered: Player Average: 81.69, League Average: 82.49, Difference: -0.80, Percent Difference: -0.97%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: -0.00, Percent Difference: -4.28%
#
# **Performance under venue_id: 672765**
# - Reaction_speed: Player Average: 2.93, League Average: 9.99, Difference: -7.07, Percent Difference: -70.71%
# - Distance_covered: Player Average: 69.07, League Average: 81.58, Difference: -12.51, Percent Difference: -15.33%
# - Catch_probability: Player Average: 0.04, League Average: 0.06, Difference: -0.02, Percent Difference: -26.97%
#
# **Performance under venue_id: 679024**
# - Reaction_speed: Player Average: 19.34, League Average: 13.40, Difference: 5.94, Percent Difference: 44.31%
# - Distance_covered: Player Average: 99.04, League Average: 87.39, Difference: 11.64, Percent Difference: 13.32%
# - Catch_probability: Player Average: 0.04, League Average: 0.05, Difference: -0.02, Percent Difference: -30.24%
#
# **Performance under venue_id: 679032**
# - Reaction_speed: Player Average: 19.52, League Average: 13.54, Difference: 5.98, Percent Difference: 44.15%
# - Distance_covered: Player Average: 99.40, League Average: 82.80, Difference: 16.59, Percent Difference: 20.04%
# - Catch_probability: Player Average: 0.03, League Average: 0.06, Difference: -0.03, Percent Difference: -47.26%
#
# **Performance under venue_id: 672656**
# - Reaction_speed: Player Average: 14.14, League Average: 11.98, Difference: 2.16, Percent Difference: 18.06%
# - Distance_covered: Player Average: 87.40, League Average: 80.86, Difference: 6.54, Percent Difference: 8.09%
# - Catch_probability: Player Average: 0.08, League Average: 0.06, Difference: 0.02, Percent Difference: 25.70%
#
# **Performance under venue_id: 678922**
# - Reaction_speed: Player Average: 8.00, League Average: 12.91, Difference: -4.90, Percent Difference: -37.99%
# - Distance_covered: Player Average: 63.66, League Average: 85.87, Difference: -22.21, Percent Difference: -25.87%
# - Catch_probability: Player Average: 0.11, League Average: 0.05, Difference: 0.06, Percent Difference: 110.13%
#
# **Performance under venue_id: 673687**
# - Reaction_speed: Player Average: 21.06, League Average: 15.34, Difference: 5.72, Percent Difference: 37.25%
# - Distance_covered: Player Average: 107.34, League Average: 94.51, Difference: 12.82, Percent Difference: 13.57%
# - Catch_probability: Player Average: 0.03, League Average: 0.03, Difference: -0.00, Percent Difference: -1.90%
#
# **Performance under venue_id: 678875**
# - Reaction_speed: Player Average: 14.87, League Average: 11.77, Difference: 3.10, Percent Difference: 26.34%
# - Distance_covered: Player Average: 69.50, League Average: 78.14, Difference: -8.64, Percent Difference: -11.06%
# - Catch_probability: Player Average: 0.11, League Average: 0.06, Difference: 0.05, Percent Difference: 75.74%
#
# **Performance under venue_id: 678887**
# - Reaction_speed: Player Average: 13.22, League Average: 13.44, Difference: -0.22, Percent Difference: -1.63%
# - Distance_covered: Player Average: 78.04, League Average: 80.60, Difference: -2.56, Percent Difference: -3.18%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 2.66%
#
# **Performance under venue_id: 673519**
# - Reaction_speed: Player Average: 11.10, League Average: 13.74, Difference: -2.63, Percent Difference: -19.18%
# - Distance_covered: Player Average: 89.38, League Average: 83.05, Difference: 6.34, Percent Difference: 7.63%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 0.81%
#
# **Performance under venue_id: 678928**
# - Reaction_speed: Player Average: 21.00, League Average: 12.20, Difference: 8.81, Percent Difference: 72.19%
# - Distance_covered: Player Average: 115.79, League Average: 94.34, Difference: 21.45, Percent Difference: 22.74%
# - Catch_probability: Player Average: 0.02, League Average: 0.04, Difference: -0.01, Percent Difference: -39.12%
#
# **Performance under count_scenario: 0-2-0-Late**
# - Reaction_speed: Player Average: 16.85, League Average: 12.44, Difference: 4.41, Percent Difference: 35.49%
# - Distance_covered: Player Average: 66.77, League Average: 79.55, Difference: -12.79, Percent Difference: -16.08%
# - Catch_probability: Player Average: 0.15, League Average: 0.05, Difference: 0.10, Percent Difference: 187.95%
#
# **Performance under count_scenario: 0-0-2-Early**
# - Reaction_speed: Player Average: 14.14, League Average: 14.05, Difference: 0.08, Percent Difference: 0.59%
# - Distance_covered: Player Average: 89.55, League Average: 81.48, Difference: 8.07, Percent Difference: 9.90%
# - Catch_probability: Player Average: 0.04, League Average: 0.06, Difference: -0.02, Percent Difference: -33.83%
#
# **Performance under count_scenario: 2-1-1-Early**
# - Reaction_speed: Player Average: 0.00, League Average: 15.76, Difference: -15.76, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 86.12, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 1-1-1-Mid**
# - Reaction_speed: Player Average: 19.59, League Average: 13.18, Difference: 6.41, Percent Difference: 48.60%
# - Distance_covered: Player Average: 98.93, League Average: 81.19, Difference: 17.74, Percent Difference: 21.85%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.01, Percent Difference: 17.78%
#
# **Performance under count_scenario: 2-1-0-Early**
# - Reaction_speed: Player Average: 4.88, League Average: 14.82, Difference: -9.94, Percent Difference: -67.05%
# - Distance_covered: Player Average: 47.05, League Average: 89.58, Difference: -42.53, Percent Difference: -47.48%
# - Catch_probability: Player Average: 0.22, League Average: 0.06, Difference: 0.17, Percent Difference: 299.05%
#
# **Performance under count_scenario: 2-0-2-Mid**
# - Reaction_speed: Player Average: 0.00, League Average: 11.87, Difference: -11.87, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 75.17, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.07, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 3-2-2-Mid**
# - Reaction_speed: Player Average: 0.00, League Average: 14.02, Difference: -14.02, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 79.92, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.05, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 1-1-0-Early**
# - Reaction_speed: Player Average: 12.97, League Average: 12.64, Difference: 0.32, Percent Difference: 2.56%
# - Distance_covered: Player Average: 74.64, League Average: 80.17, Difference: -5.53, Percent Difference: -6.90%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: -0.00, Percent Difference: -7.01%
#
# **Performance under count_scenario: 2-2-2-Early**
# - Reaction_speed: Player Average: 8.00, League Average: 12.70, Difference: -4.70, Percent Difference: -36.98%
# - Distance_covered: Player Average: 96.00, League Average: 83.72, Difference: 12.29, Percent Difference: 14.68%
# - Catch_probability: Player Average: 0.04, League Average: 0.06, Difference: -0.03, Percent Difference: -41.21%
#
# **Performance under count_scenario: 0-0-2-Mid**
# - Reaction_speed: Player Average: 15.97, League Average: 12.94, Difference: 3.03, Percent Difference: 23.38%
# - Distance_covered: Player Average: 77.91, League Average: 84.67, Difference: -6.76, Percent Difference: -7.98%
# - Catch_probability: Player Average: 0.04, League Average: 0.05, Difference: -0.02, Percent Difference: -32.25%
#
# **Performance under count_scenario: 1-1-1-Early**
# - Reaction_speed: Player Average: 5.76, League Average: 13.26, Difference: -7.51, Percent Difference: -56.60%
# - Distance_covered: Player Average: 53.42, League Average: 81.79, Difference: -28.37, Percent Difference: -34.68%
# - Catch_probability: Player Average: 0.12, League Average: 0.06, Difference: 0.06, Percent Difference: 112.80%
#
# **Performance under count_scenario: 1-2-0-Early**
# - Reaction_speed: Player Average: 9.23, League Average: 14.21, Difference: -4.98, Percent Difference: -35.04%
# - Distance_covered: Player Average: 73.54, League Average: 82.28, Difference: -8.74, Percent Difference: -10.62%
# - Catch_probability: Player Average: 0.03, League Average: 0.07, Difference: -0.04, Percent Difference: -55.84%
#
# **Performance under count_scenario: 1-1-2-Late**
# - Reaction_speed: Player Average: 9.68, League Average: 11.85, Difference: -2.18, Percent Difference: -18.36%
# - Distance_covered: Player Average: 59.69, League Average: 78.32, Difference: -18.63, Percent Difference: -23.79%
# - Catch_probability: Player Average: 0.17, League Average: 0.07, Difference: 0.10, Percent Difference: 152.75%
#
# **Performance under count_scenario: 0-1-1-Late**
# - Reaction_speed: Player Average: 20.08, League Average: 13.97, Difference: 6.11, Percent Difference: 43.73%
# - Distance_covered: Player Average: 120.26, League Average: 82.92, Difference: 37.34, Percent Difference: 45.03%
# - Catch_probability: Player Average: 0.00, League Average: 0.06, Difference: -0.06, Percent Difference: -95.21%
#
# **Performance under count_scenario: 2-0-1-Mid**
# - Reaction_speed: Player Average: 5.28, League Average: 12.26, Difference: -6.98, Percent Difference: -56.95%
# - Distance_covered: Player Average: 35.14, League Average: 87.64, Difference: -52.50, Percent Difference: -59.90%
# - Catch_probability: Player Average: 0.11, League Average: 0.05, Difference: 0.07, Percent Difference: 145.91%
#
# **Performance under count_scenario: 2-2-1-Mid**
# - Reaction_speed: Player Average: 9.05, League Average: 15.47, Difference: -6.42, Percent Difference: -41.50%
# - Distance_covered: Player Average: 180.03, League Average: 83.85, Difference: 96.18, Percent Difference: 114.72%
# - Catch_probability: Player Average: 0.00, League Average: 0.06, Difference: -0.06, Percent Difference: -99.92%
#
# **Performance under count_scenario: 1-2-1-Mid**
# - Reaction_speed: Player Average: 20.12, League Average: 14.08, Difference: 6.04, Percent Difference: 42.91%
# - Distance_covered: Player Average: 81.07, League Average: 82.70, Difference: -1.63, Percent Difference: -1.97%
# - Catch_probability: Player Average: 0.05, League Average: 0.06, Difference: -0.01, Percent Difference: -14.69%
#
# **Performance under count_scenario: 0-0-1-Late**
# - Reaction_speed: Player Average: 12.35, League Average: 13.16, Difference: -0.81, Percent Difference: -6.14%
# - Distance_covered: Player Average: 63.46, League Average: 80.95, Difference: -17.49, Percent Difference: -21.61%
# - Catch_probability: Player Average: 0.05, League Average: 0.07, Difference: -0.02, Percent Difference: -23.01%
#
# **Performance under count_scenario: 2-1-2-Early**
# - Reaction_speed: Player Average: 11.46, League Average: 12.74, Difference: -1.28, Percent Difference: -10.04%
# - Distance_covered: Player Average: 78.43, League Average: 78.52, Difference: -0.09, Percent Difference: -0.12%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.04, Percent Difference: -59.73%
#
# **Performance under count_scenario: 0-1-0-Early**
# - Reaction_speed: Player Average: 5.64, League Average: 14.63, Difference: -8.98, Percent Difference: -61.42%
# - Distance_covered: Player Average: 81.31, League Average: 84.89, Difference: -3.58, Percent Difference: -4.22%
# - Catch_probability: Player Average: 0.04, League Average: 0.05, Difference: -0.02, Percent Difference: -33.07%
#
# **Performance under count_scenario: 0-0-2-Late**
# - Reaction_speed: Player Average: 14.46, League Average: 13.30, Difference: 1.16, Percent Difference: 8.69%
# - Distance_covered: Player Average: 80.04, League Average: 83.88, Difference: -3.84, Percent Difference: -4.58%
# - Catch_probability: Player Average: 0.14, League Average: 0.05, Difference: 0.09, Percent Difference: 170.88%
#
# **Performance under count_scenario: 3-1-0-Early**
# - Reaction_speed: Player Average: 15.72, League Average: 11.42, Difference: 4.30, Percent Difference: 37.62%
# - Distance_covered: Player Average: 116.15, League Average: 76.42, Difference: 39.73, Percent Difference: 51.99%
# - Catch_probability: Player Average: 0.00, League Average: 0.08, Difference: -0.08, Percent Difference: -98.22%
#
# **Performance under count_scenario: 0-1-1-Early**
# - Reaction_speed: Player Average: 22.16, League Average: 14.95, Difference: 7.21, Percent Difference: 48.19%
# - Distance_covered: Player Average: 84.22, League Average: 84.61, Difference: -0.40, Percent Difference: -0.47%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.01, Percent Difference: 22.06%
#
# **Performance under count_scenario: 1-0-2-Mid**
# - Reaction_speed: Player Average: 7.38, League Average: 14.33, Difference: -6.94, Percent Difference: -48.47%
# - Distance_covered: Player Average: 71.86, League Average: 85.20, Difference: -13.34, Percent Difference: -15.66%
# - Catch_probability: Player Average: 0.07, League Average: 0.05, Difference: 0.02, Percent Difference: 32.42%
#
# **Performance under count_scenario: 1-1-0-Mid**
# - Reaction_speed: Player Average: 18.19, League Average: 13.41, Difference: 4.78, Percent Difference: 35.64%
# - Distance_covered: Player Average: 114.73, League Average: 84.86, Difference: 29.86, Percent Difference: 35.19%
# - Catch_probability: Player Average: 0.01, League Average: 0.05, Difference: -0.04, Percent Difference: -85.56%
#
# **Performance under count_scenario: 0-1-0-Mid**
# - Reaction_speed: Player Average: 21.27, League Average: 13.24, Difference: 8.04, Percent Difference: 60.71%
# - Distance_covered: Player Average: 102.57, League Average: 86.40, Difference: 16.17, Percent Difference: 18.71%
# - Catch_probability: Player Average: 0.02, League Average: 0.05, Difference: -0.02, Percent Difference: -49.19%
#
# **Performance under count_scenario: 0-0-0-Mid**
# - Reaction_speed: Player Average: 16.34, League Average: 11.86, Difference: 4.48, Percent Difference: 37.73%
# - Distance_covered: Player Average: 83.67, League Average: 77.61, Difference: 6.07, Percent Difference: 7.82%
# - Catch_probability: Player Average: 0.04, League Average: 0.06, Difference: -0.02, Percent Difference: -33.41%
#
# **Performance under count_scenario: 3-0-1-Early**
# - Reaction_speed: Player Average: 22.64, League Average: 12.13, Difference: 10.50, Percent Difference: 86.55%
# - Distance_covered: Player Average: 74.32, League Average: 77.07, Difference: -2.75, Percent Difference: -3.57%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.05, Percent Difference: -74.84%
#
# **Performance under count_scenario: 1-2-1-Late**
# - Reaction_speed: Player Average: 8.42, League Average: 15.40, Difference: -6.98, Percent Difference: -45.35%
# - Distance_covered: Player Average: 61.19, League Average: 86.80, Difference: -25.61, Percent Difference: -29.51%
# - Catch_probability: Player Average: 0.05, League Average: 0.05, Difference: 0.00, Percent Difference: 3.64%
#
# **Performance under count_scenario: 0-2-2-Mid**
# - Reaction_speed: Player Average: 7.14, League Average: 12.49, Difference: -5.34, Percent Difference: -42.80%
# - Distance_covered: Player Average: 45.14, League Average: 78.16, Difference: -33.02, Percent Difference: -42.24%
# - Catch_probability: Player Average: 0.18, League Average: 0.06, Difference: 0.11, Percent Difference: 180.63%
#
# **Performance under count_scenario: 0-0-1-Early**
# - Reaction_speed: Player Average: 15.44, League Average: 12.59, Difference: 2.86, Percent Difference: 22.69%
# - Distance_covered: Player Average: 90.43, League Average: 78.70, Difference: 11.74, Percent Difference: 14.92%
# - Catch_probability: Player Average: 0.05, League Average: 0.07, Difference: -0.02, Percent Difference: -23.02%
#
# **Performance under count_scenario: 3-1-0-Mid**
# - Reaction_speed: Player Average: 20.49, League Average: 12.42, Difference: 8.07, Percent Difference: 64.93%
# - Distance_covered: Player Average: 92.48, League Average: 83.53, Difference: 8.95, Percent Difference: 10.71%
# - Catch_probability: Player Average: 0.03, League Average: 0.05, Difference: -0.02, Percent Difference: -35.92%
#
# **Performance under count_scenario: 2-0-0-Late**
# - Reaction_speed: Player Average: 0.00, League Average: 12.74, Difference: -12.74, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 83.00, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.04, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 2-2-0-Mid**
# - Reaction_speed: Player Average: 14.71, League Average: 14.55, Difference: 0.16, Percent Difference: 1.08%
# - Distance_covered: Player Average: 108.15, League Average: 82.98, Difference: 25.17, Percent Difference: 30.34%
# - Catch_probability: Player Average: 0.01, League Average: 0.06, Difference: -0.05, Percent Difference: -85.26%
#
# **Performance under count_scenario: 3-1-0-Late**
# - Reaction_speed: Player Average: 0.00, League Average: 12.50, Difference: -12.50, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 74.36, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 1-0-1-Early**
# - Reaction_speed: Player Average: 15.41, League Average: 12.15, Difference: 3.26, Percent Difference: 26.82%
# - Distance_covered: Player Average: 99.79, League Average: 78.14, Difference: 21.64, Percent Difference: 27.70%
# - Catch_probability: Player Average: 0.01, League Average: 0.07, Difference: -0.06, Percent Difference: -89.09%
#
# **Performance under count_scenario: 3-2-2-Early**
# - Reaction_speed: Player Average: 18.02, League Average: 13.37, Difference: 4.65, Percent Difference: 34.79%
# - Distance_covered: Player Average: 118.55, League Average: 86.71, Difference: 31.85, Percent Difference: 36.73%
# - Catch_probability: Player Average: 0.03, League Average: 0.05, Difference: -0.02, Percent Difference: -31.71%
#
# **Performance under count_scenario: 0-1-2-Mid**
# - Reaction_speed: Player Average: 11.21, League Average: 14.27, Difference: -3.06, Percent Difference: -21.44%
# - Distance_covered: Player Average: 76.89, League Average: 85.72, Difference: -8.83, Percent Difference: -10.30%
# - Catch_probability: Player Average: 0.12, League Average: 0.06, Difference: 0.06, Percent Difference: 103.86%
#
# **Performance under count_scenario: 2-2-0-Late**
# - Reaction_speed: Player Average: 18.59, League Average: 13.50, Difference: 5.09, Percent Difference: 37.73%
# - Distance_covered: Player Average: 123.99, League Average: 83.74, Difference: 40.25, Percent Difference: 48.07%
# - Catch_probability: Player Average: 0.00, League Average: 0.07, Difference: -0.06, Percent Difference: -93.94%
#
# **Performance under count_scenario: 2-2-2-Late**
# - Reaction_speed: Player Average: 6.11, League Average: 14.84, Difference: -8.73, Percent Difference: -58.83%
# - Distance_covered: Player Average: 39.81, League Average: 86.01, Difference: -46.20, Percent Difference: -53.71%
# - Catch_probability: Player Average: 0.12, League Average: 0.05, Difference: 0.07, Percent Difference: 137.97%
#
# **Performance under count_scenario: 0-2-1-Mid**
# - Reaction_speed: Player Average: 2.88, League Average: 13.77, Difference: -10.89, Percent Difference: -79.11%
# - Distance_covered: Player Average: 89.63, League Average: 84.70, Difference: 4.93, Percent Difference: 5.82%
# - Catch_probability: Player Average: 0.01, League Average: 0.06, Difference: -0.05, Percent Difference: -86.70%
#
# **Performance under count_scenario: 1-0-1-Mid**
# - Reaction_speed: Player Average: 23.62, League Average: 13.20, Difference: 10.42, Percent Difference: 78.96%
# - Distance_covered: Player Average: 101.09, League Average: 81.00, Difference: 20.10, Percent Difference: 24.81%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.05, Percent Difference: -73.82%
#
# **Performance under count_scenario: 3-2-0-Late**
# - Reaction_speed: Player Average: 13.97, League Average: 15.45, Difference: -1.48, Percent Difference: -9.60%
# - Distance_covered: Player Average: 102.89, League Average: 84.91, Difference: 17.97, Percent Difference: 21.17%
# - Catch_probability: Player Average: 0.02, League Average: 0.05, Difference: -0.03, Percent Difference: -59.14%
#
# **Performance under count_scenario: 0-0-0-Late**
# - Reaction_speed: Player Average: 12.87, League Average: 12.36, Difference: 0.51, Percent Difference: 4.16%
# - Distance_covered: Player Average: 79.83, League Average: 82.48, Difference: -2.65, Percent Difference: -3.22%
# - Catch_probability: Player Average: 0.05, League Average: 0.06, Difference: -0.01, Percent Difference: -22.55%
#
# **Performance under count_scenario: 1-0-0-Early**
# - Reaction_speed: Player Average: 42.01, League Average: 12.75, Difference: 29.26, Percent Difference: 229.48%
# - Distance_covered: Player Average: 142.52, League Average: 78.95, Difference: 63.57, Percent Difference: 80.52%
# - Catch_probability: Player Average: 0.01, League Average: 0.06, Difference: -0.05, Percent Difference: -88.54%
#
# **Performance under count_scenario: 2-1-0-Mid**
# - Reaction_speed: Player Average: 10.81, League Average: 13.74, Difference: -2.93, Percent Difference: -21.32%
# - Distance_covered: Player Average: 70.37, League Average: 88.20, Difference: -17.83, Percent Difference: -20.21%
# - Catch_probability: Player Average: 0.05, League Average: 0.05, Difference: -0.01, Percent Difference: -11.62%
#
# **Performance under count_scenario: 2-2-2-Mid**
# - Reaction_speed: Player Average: 12.73, League Average: 15.81, Difference: -3.08, Percent Difference: -19.51%
# - Distance_covered: Player Average: 73.25, League Average: 87.53, Difference: -14.28, Percent Difference: -16.31%
# - Catch_probability: Player Average: 0.05, League Average: 0.05, Difference: 0.00, Percent Difference: 5.76%
#
# **Performance under count_scenario: 1-0-1-Late**
# - Reaction_speed: Player Average: 8.01, League Average: 11.12, Difference: -3.11, Percent Difference: -27.98%
# - Distance_covered: Player Average: 53.14, League Average: 73.54, Difference: -20.39, Percent Difference: -27.73%
# - Catch_probability: Player Average: 0.10, League Average: 0.07, Difference: 0.03, Percent Difference: 51.51%
#
# **Performance under count_scenario: 1-2-2-Mid**
# - Reaction_speed: Player Average: 4.49, League Average: 15.32, Difference: -10.82, Percent Difference: -70.66%
# - Distance_covered: Player Average: 37.23, League Average: 86.58, Difference: -49.35, Percent Difference: -57.00%
# - Catch_probability: Player Average: 0.11, League Average: 0.05, Difference: 0.06, Percent Difference: 114.67%
#
# **Performance under count_scenario: 0-0-1-Mid**
# - Reaction_speed: Player Average: 13.52, League Average: 13.04, Difference: 0.48, Percent Difference: 3.67%
# - Distance_covered: Player Average: 82.17, League Average: 81.57, Difference: 0.59, Percent Difference: 0.72%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.04, Percent Difference: -60.38%
#
# **Performance under count_scenario: 1-2-0-Mid**
# - Reaction_speed: Player Average: 11.34, League Average: 14.18, Difference: -2.84, Percent Difference: -20.02%
# - Distance_covered: Player Average: 60.14, League Average: 83.73, Difference: -23.59, Percent Difference: -28.17%
# - Catch_probability: Player Average: 0.15, League Average: 0.06, Difference: 0.10, Percent Difference: 166.75%
#
# **Performance under count_scenario: 2-0-2-Late**
# - Reaction_speed: Player Average: 21.22, League Average: 12.27, Difference: 8.95, Percent Difference: 72.94%
# - Distance_covered: Player Average: 101.42, League Average: 80.33, Difference: 21.09, Percent Difference: 26.25%
# - Catch_probability: Player Average: 0.01, League Average: 0.04, Difference: -0.04, Percent Difference: -81.62%
#
# **Performance under count_scenario: 3-2-2-Late**
# - Reaction_speed: Player Average: 13.85, League Average: 12.34, Difference: 1.51, Percent Difference: 12.26%
# - Distance_covered: Player Average: 80.34, League Average: 80.25, Difference: 0.09, Percent Difference: 0.11%
# - Catch_probability: Player Average: 0.10, League Average: 0.06, Difference: 0.04, Percent Difference: 73.95%
#
# **Performance under count_scenario: 1-2-2-Early**
# - Reaction_speed: Player Average: 14.49, League Average: 14.78, Difference: -0.30, Percent Difference: -2.00%
# - Distance_covered: Player Average: 81.00, League Average: 84.27, Difference: -3.27, Percent Difference: -3.88%
# - Catch_probability: Player Average: 0.13, League Average: 0.05, Difference: 0.08, Percent Difference: 148.29%
#
# **Performance under count_scenario: 2-0-1-Early**
# - Reaction_speed: Player Average: 9.56, League Average: 13.77, Difference: -4.21, Percent Difference: -30.58%
# - Distance_covered: Player Average: 55.07, League Average: 87.13, Difference: -32.06, Percent Difference: -36.79%
# - Catch_probability: Player Average: 0.05, League Average: 0.05, Difference: -0.00, Percent Difference: -3.63%
#
# **Performance under count_scenario: 1-0-2-Early**
# - Reaction_speed: Player Average: 4.72, League Average: 11.91, Difference: -7.19, Percent Difference: -60.35%
# - Distance_covered: Player Average: 51.07, League Average: 79.09, Difference: -28.02, Percent Difference: -35.42%
# - Catch_probability: Player Average: 0.09, League Average: 0.07, Difference: 0.03, Percent Difference: 41.53%
#
# **Performance under count_scenario: 3-2-0-Early**
# - Reaction_speed: Player Average: 19.29, League Average: 13.05, Difference: 6.24, Percent Difference: 47.77%
# - Distance_covered: Player Average: 105.57, League Average: 84.14, Difference: 21.43, Percent Difference: 25.47%
# - Catch_probability: Player Average: 0.00, League Average: 0.06, Difference: -0.06, Percent Difference: -95.24%
#
# **Performance under count_scenario: 3-1-1-Early**
# - Reaction_speed: Player Average: 0.00, League Average: 11.18, Difference: -11.18, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 78.44, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 2-2-0-Early**
# - Reaction_speed: Player Average: 18.94, League Average: 14.09, Difference: 4.85, Percent Difference: 34.38%
# - Distance_covered: Player Average: 75.20, League Average: 85.21, Difference: -10.01, Percent Difference: -11.75%
# - Catch_probability: Player Average: 0.03, League Average: 0.05, Difference: -0.03, Percent Difference: -48.67%
#
# **Performance under count_scenario: 0-0-0-Early**
# - Reaction_speed: Player Average: 15.46, League Average: 12.63, Difference: 2.83, Percent Difference: 22.39%
# - Distance_covered: Player Average: 85.84, League Average: 79.56, Difference: 6.28, Percent Difference: 7.89%
# - Catch_probability: Player Average: 0.03, League Average: 0.07, Difference: -0.04, Percent Difference: -53.31%
#
# **Performance under count_scenario: 1-0-2-Late**
# - Reaction_speed: Player Average: 2.68, League Average: 13.84, Difference: -11.16, Percent Difference: -80.63%
# - Distance_covered: Player Average: 63.82, League Average: 86.90, Difference: -23.09, Percent Difference: -26.57%
# - Catch_probability: Player Average: 0.10, League Average: 0.05, Difference: 0.04, Percent Difference: 75.03%
#
# **Performance under count_scenario: 1-0-0-Late**
# - Reaction_speed: Player Average: 22.87, League Average: 14.71, Difference: 8.16, Percent Difference: 55.44%
# - Distance_covered: Player Average: 84.12, League Average: 82.89, Difference: 1.23, Percent Difference: 1.49%
# - Catch_probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 3.75%
#
# **Performance under count_scenario: 1-1-2-Early**
# - Reaction_speed: Player Average: 21.77, League Average: 11.19, Difference: 10.58, Percent Difference: 94.60%
# - Distance_covered: Player Average: 112.33, League Average: 76.06, Difference: 36.28, Percent Difference: 47.70%
# - Catch_probability: Player Average: 0.00, League Average: 0.07, Difference: -0.07, Percent Difference: -94.15%
#
# **Performance under count_scenario: 2-1-1-Mid**
# - Reaction_speed: Player Average: 3.76, League Average: 12.69, Difference: -8.93, Percent Difference: -70.35%
# - Distance_covered: Player Average: 43.18, League Average: 77.22, Difference: -34.04, Percent Difference: -44.09%
# - Catch_probability: Player Average: 0.09, League Average: 0.06, Difference: 0.02, Percent Difference: 37.32%
#
# **Performance under count_scenario: 1-1-1-Late**
# - Reaction_speed: Player Average: 20.67, League Average: 13.90, Difference: 6.77, Percent Difference: 48.74%
# - Distance_covered: Player Average: 101.29, League Average: 81.96, Difference: 19.33, Percent Difference: 23.59%
# - Catch_probability: Player Average: 0.00, League Average: 0.05, Difference: -0.05, Percent Difference: -92.11%
#
# **Performance under count_scenario: 3-2-1-Early**
# - Reaction_speed: Player Average: 18.40, League Average: 13.13, Difference: 5.27, Percent Difference: 40.12%
# - Distance_covered: Player Average: 95.65, League Average: 80.25, Difference: 15.41, Percent Difference: 19.20%
# - Catch_probability: Player Average: 0.04, League Average: 0.06, Difference: -0.01, Percent Difference: -26.13%
#
# **Performance under count_scenario: 0-2-2-Late**
# - Reaction_speed: Player Average: 29.03, League Average: 14.18, Difference: 14.85, Percent Difference: 104.76%
# - Distance_covered: Player Average: 118.76, League Average: 86.08, Difference: 32.68, Percent Difference: 37.96%
# - Catch_probability: Player Average: 0.00, League Average: 0.05, Difference: -0.05, Percent Difference: -95.92%
#
# **Performance under count_scenario: 0-2-1-Late**
# - Reaction_speed: Player Average: 6.80, League Average: 15.15, Difference: -8.35, Percent Difference: -55.10%
# - Distance_covered: Player Average: 30.55, League Average: 84.33, Difference: -53.78, Percent Difference: -63.77%
# - Catch_probability: Player Average: 0.15, League Average: 0.06, Difference: 0.09, Percent Difference: 163.11%
#
# **Performance under count_scenario: 0-1-0-Late**
# - Reaction_speed: Player Average: 26.64, League Average: 13.63, Difference: 13.01, Percent Difference: 95.40%
# - Distance_covered: Player Average: 90.97, League Average: 80.95, Difference: 10.02, Percent Difference: 12.38%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.04, Percent Difference: -72.99%
#
# **Performance under count_scenario: 2-0-1-Late**
# - Reaction_speed: Player Average: 0.00, League Average: 11.62, Difference: -11.62, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 81.21, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.05, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 2-1-1-Late**
# - Reaction_speed: Player Average: 15.73, League Average: 11.83, Difference: 3.90, Percent Difference: 33.00%
# - Distance_covered: Player Average: 65.63, League Average: 76.20, Difference: -10.58, Percent Difference: -13.88%
# - Catch_probability: Player Average: 0.16, League Average: 0.08, Difference: 0.08, Percent Difference: 105.87%
#
# **Performance under count_scenario: 2-2-1-Early**
# - Reaction_speed: Player Average: 5.70, League Average: 12.20, Difference: -6.50, Percent Difference: -53.26%
# - Distance_covered: Player Average: 87.51, League Average: 81.95, Difference: 5.57, Percent Difference: 6.79%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.04, Percent Difference: -68.78%
#
# **Performance under count_scenario: 3-1-1-Mid**
# - Reaction_speed: Player Average: 16.18, League Average: 13.12, Difference: 3.06, Percent Difference: 23.29%
# - Distance_covered: Player Average: 85.87, League Average: 78.86, Difference: 7.01, Percent Difference: 8.89%
# - Catch_probability: Player Average: 0.02, League Average: 0.06, Difference: -0.04, Percent Difference: -66.97%
#
# **Performance under count_scenario: 0-1-2-Early**
# - Reaction_speed: Player Average: 8.22, League Average: 13.84, Difference: -5.62, Percent Difference: -40.61%
# - Distance_covered: Player Average: 70.26, League Average: 83.84, Difference: -13.58, Percent Difference: -16.20%
# - Catch_probability: Player Average: 0.13, League Average: 0.06, Difference: 0.08, Percent Difference: 131.39%
#
# **Performance under count_scenario: 0-2-2-Early**
# - Reaction_speed: Player Average: 8.23, League Average: 14.50, Difference: -6.27, Percent Difference: -43.22%
# - Distance_covered: Player Average: 62.17, League Average: 83.81, Difference: -21.64, Percent Difference: -25.82%
# - Catch_probability: Player Average: 0.04, League Average: 0.05, Difference: -0.01, Percent Difference: -20.44%
#
# **Performance under count_scenario: 0-1-1-Mid**
# - Reaction_speed: Player Average: 12.83, League Average: 12.88, Difference: -0.05, Percent Difference: -0.36%
# - Distance_covered: Player Average: 79.17, League Average: 80.28, Difference: -1.11, Percent Difference: -1.38%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.01, Percent Difference: 16.22%
#
# **Performance under count_scenario: 2-1-2-Mid**
# - Reaction_speed: Player Average: 7.74, League Average: 12.59, Difference: -4.85, Percent Difference: -38.49%
# - Distance_covered: Player Average: 65.05, League Average: 82.84, Difference: -17.78, Percent Difference: -21.47%
# - Catch_probability: Player Average: 0.15, League Average: 0.06, Difference: 0.09, Percent Difference: 165.67%
#
# **Performance under count_scenario: 1-2-1-Early**
# - Reaction_speed: Player Average: 5.45, League Average: 15.11, Difference: -9.67, Percent Difference: -63.95%
# - Distance_covered: Player Average: 70.24, League Average: 84.64, Difference: -14.40, Percent Difference: -17.02%
# - Catch_probability: Player Average: 0.04, League Average: 0.05, Difference: -0.01, Percent Difference: -22.93%
#
# **Performance under count_scenario: 1-2-0-Late**
# - Reaction_speed: Player Average: 17.63, League Average: 15.84, Difference: 1.79, Percent Difference: 11.27%
# - Distance_covered: Player Average: 94.67, League Average: 87.38, Difference: 7.28, Percent Difference: 8.33%
# - Catch_probability: Player Average: 0.06, League Average: 0.05, Difference: 0.01, Percent Difference: 25.46%
#
# **Performance under count_scenario: 2-0-0-Mid**
# - Reaction_speed: Player Average: 5.46, League Average: 14.28, Difference: -8.82, Percent Difference: -61.77%
# - Distance_covered: Player Average: 45.39, League Average: 78.25, Difference: -32.87, Percent Difference: -42.00%
# - Catch_probability: Player Average: 0.12, League Average: 0.07, Difference: 0.04, Percent Difference: 58.13%
#
# **Performance under count_scenario: 0-2-1-Early**
# - Reaction_speed: Player Average: 2.06, League Average: 13.79, Difference: -11.73, Percent Difference: -85.09%
# - Distance_covered: Player Average: 20.96, League Average: 81.43, Difference: -60.47, Percent Difference: -74.26%
# - Catch_probability: Player Average: 0.25, League Average: 0.05, Difference: 0.20, Percent Difference: 364.01%
#
# **Performance under count_scenario: 0-2-0-Mid**
# - Reaction_speed: Player Average: 15.70, League Average: 16.02, Difference: -0.33, Percent Difference: -2.03%
# - Distance_covered: Player Average: 124.12, League Average: 90.81, Difference: 33.32, Percent Difference: 36.69%
# - Catch_probability: Player Average: 0.00, League Average: 0.04, Difference: -0.04, Percent Difference: -97.59%
#
# **Performance under count_scenario: 1-0-0-Mid**
# - Reaction_speed: Player Average: 15.39, League Average: 12.07, Difference: 3.32, Percent Difference: 27.49%
# - Distance_covered: Player Average: 67.57, League Average: 78.02, Difference: -10.45, Percent Difference: -13.39%
# - Catch_probability: Player Average: 0.11, League Average: 0.07, Difference: 0.04, Percent Difference: 49.93%
#
# **Performance under count_scenario: 2-2-1-Late**
# - Reaction_speed: Player Average: 30.39, League Average: 12.48, Difference: 17.91, Percent Difference: 143.56%
# - Distance_covered: Player Average: 114.28, League Average: 82.62, Difference: 31.66, Percent Difference: 38.32%
# - Catch_probability: Player Average: 0.01, League Average: 0.05, Difference: -0.05, Percent Difference: -85.84%
#
# **Performance under count_scenario: 3-1-2-Early**
# - Reaction_speed: Player Average: 0.00, League Average: 12.15, Difference: -12.15, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 79.97, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 1-2-2-Late**
# - Reaction_speed: Player Average: 5.31, League Average: 14.01, Difference: -8.70, Percent Difference: -62.10%
# - Distance_covered: Player Average: 87.04, League Average: 86.97, Difference: 0.08, Percent Difference: 0.09%
# - Catch_probability: Player Average: 0.02, League Average: 0.05, Difference: -0.03, Percent Difference: -56.49%
#
# **Performance under count_scenario: 0-1-2-Late**
# - Reaction_speed: Player Average: 32.65, League Average: 15.42, Difference: 17.23, Percent Difference: 111.78%
# - Distance_covered: Player Average: 127.27, League Average: 89.30, Difference: 37.97, Percent Difference: 42.52%
# - Catch_probability: Player Average: 0.00, League Average: 0.04, Difference: -0.04, Percent Difference: -89.36%
#
# **Performance under count_scenario: 3-2-1-Mid**
# - Reaction_speed: Player Average: 43.93, League Average: 12.54, Difference: 31.39, Percent Difference: 250.30%
# - Distance_covered: Player Average: 125.20, League Average: 81.91, Difference: 43.29, Percent Difference: 52.86%
# - Catch_probability: Player Average: 0.00, League Average: 0.05, Difference: -0.05, Percent Difference: -94.67%
#
# **Performance under count_scenario: 1-1-2-Mid**
# - Reaction_speed: Player Average: 15.55, League Average: 12.94, Difference: 2.61, Percent Difference: 20.17%
# - Distance_covered: Player Average: 94.39, League Average: 82.66, Difference: 11.73, Percent Difference: 14.20%
# - Catch_probability: Player Average: 0.03, League Average: 0.06, Difference: -0.03, Percent Difference: -46.72%
#
# **Performance under count_scenario: 1-1-0-Late**
# - Reaction_speed: Player Average: 0.00, League Average: 15.66, Difference: -15.66, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 85.81, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 3-2-1-Late**
# - Reaction_speed: Player Average: 19.15, League Average: 13.23, Difference: 5.93, Percent Difference: 44.80%
# - Distance_covered: Player Average: 109.47, League Average: 80.94, Difference: 28.53, Percent Difference: 35.25%
# - Catch_probability: Player Average: 0.01, League Average: 0.06, Difference: -0.06, Percent Difference: -85.57%
#
# **Performance under count_scenario: 3-2-0-Mid**
# - Reaction_speed: Player Average: 10.36, League Average: 11.50, Difference: -1.14, Percent Difference: -9.89%
# - Distance_covered: Player Average: 53.62, League Average: 77.66, Difference: -24.04, Percent Difference: -30.96%
# - Catch_probability: Player Average: 0.07, League Average: 0.06, Difference: 0.01, Percent Difference: 20.12%
#
# **Performance under count_scenario: 3-1-2-Late**
# - Reaction_speed: Player Average: 2.19, League Average: 14.19, Difference: -12.00, Percent Difference: -84.58%
# - Distance_covered: Player Average: 23.62, League Average: 80.09, Difference: -56.48, Percent Difference: -70.51%
# - Catch_probability: Player Average: 0.22, League Average: 0.06, Difference: 0.16, Percent Difference: 255.32%
#
# **Performance under count_scenario: 3-1-2-Mid**
# - Reaction_speed: Player Average: 34.76, League Average: 9.69, Difference: 25.07, Percent Difference: 258.79%
# - Distance_covered: Player Average: 114.01, League Average: 67.07, Difference: 46.94, Percent Difference: 69.99%
# - Catch_probability: Player Average: 0.01, League Average: 0.09, Difference: -0.08, Percent Difference: -91.84%
#
# **Performance under count_scenario: 3-1-1-Late**
# - Reaction_speed: Player Average: 47.83, League Average: 12.03, Difference: 35.81, Percent Difference: 297.76%
# - Distance_covered: Player Average: 126.16, League Average: 84.71, Difference: 41.46, Percent Difference: 48.94%
# - Catch_probability: Player Average: 0.00, League Average: 0.06, Difference: -0.06, Percent Difference: -98.49%
#
# **Performance under count_scenario: 2-1-2-Late**
# - Reaction_speed: Player Average: 3.64, League Average: 12.35, Difference: -8.71, Percent Difference: -70.51%
# - Distance_covered: Player Average: 62.54, League Average: 85.15, Difference: -22.61, Percent Difference: -26.55%
# - Catch_probability: Player Average: 0.03, League Average: 0.07, Difference: -0.04, Percent Difference: -54.16%
#
# **Performance under count_scenario: 0-2-0-Early**
# - Reaction_speed: Player Average: 5.66, League Average: 15.75, Difference: -10.09, Percent Difference: -64.05%
# - Distance_covered: Player Average: 33.41, League Average: 85.90, Difference: -52.49, Percent Difference: -61.11%
# - Catch_probability: Player Average: 0.14, League Average: 0.05, Difference: 0.08, Percent Difference: 161.58%
#
# **Performance under count_scenario: 3-0-2-Mid**
# - Reaction_speed: Player Average: 0.00, League Average: 16.52, Difference: -16.52, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 85.71, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 2-0-2-Early**
# - Reaction_speed: Player Average: 0.00, League Average: 12.24, Difference: -12.24, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 82.68, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.06, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 2-1-0-Late**
# - Reaction_speed: Player Average: 4.31, League Average: 13.28, Difference: -8.97, Percent Difference: -67.55%
# - Distance_covered: Player Average: 80.09, League Average: 80.33, Difference: -0.24, Percent Difference: -0.30%
# - Catch_probability: Player Average: 0.01, League Average: 0.06, Difference: -0.05, Percent Difference: -76.94%
#
# **Performance under count_scenario: 2-0-0-Early**
# - Reaction_speed: Player Average: 27.10, League Average: 10.94, Difference: 16.16, Percent Difference: 147.74%
# - Distance_covered: Player Average: 181.30, League Average: 77.88, Difference: 103.42, Percent Difference: 132.80%
# - Catch_probability: Player Average: 0.00, League Average: 0.06, Difference: -0.06, Percent Difference: -99.94%
#
# **Performance under count_scenario: 3-0-2-Late**
# - Reaction_speed: Player Average: 0.00, League Average: 2.51, Difference: -2.51, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 48.45, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.13, Difference: nan, Percent Difference: nan%
#
# **Performance under count_scenario: 3-0-0-Mid**
# - Reaction_speed: Player Average: 0.00, League Average: 5.50, Difference: -5.50, Percent Difference: -100.00%
# - Distance_covered: Player Average: nan, League Average: 54.07, Difference: nan, Percent Difference: nan%
# - Catch_probability: Player Average: nan, League Average: 0.10, Difference: nan, Percent Difference: nan%

# %% [markdown]
# # Scouting Report: Player ID 15411
#
# Player Overview:
# This report provides an in-depth analysis of the defensive performance of Player ID 15411, using advanced metrics and comparisons against the league averages and cluster groupings. Key metrics used include reaction speed, distance covered, and catch probability. Each metric is evaluated at an aggregate level and within specific game conditions.
# League Comparison Analysis:
# Metric	Player Average	League Average	Difference	Percent Difference	Player Percentile	League Percentile
# Reaction Speed	13.65	13.43	0.22	1.62%	50.15	50.00
# Distance Covered	83.11	82.38	0.73	0.89%	50.15	50.00
# Catch Probability	0.061	0.058	0.003	5.21%	50.15	50.00
#
# Performance Highlights:
#
#     Reaction Speed: The player's average reaction speed of 13.65 is slightly above the league average of 13.43, with a 1.62% difference, placing them in the 50th percentile for this metric.
#     Distance Covered: The player covers an average distance of 83.11, slightly higher than the league's average of 82.38, with a difference of 0.73. This results in a similar percentile ranking as reaction speed.
#     Catch Probability: The player's catch probability stands at 0.061, exceeding the league average of 0.058. This 5.21% increase signifies strong performance in difficult catch scenarios.
#
# Condition-Based Performance Analysis:
#
# 1. Performance under Temperature Category: Moderate
#
#     Reaction Speed: Player Average: 14.19, League Average: 13.40, Difference: 0.79, Percent Difference: 5.89%
#     Distance Covered: Player Average: 82.46, League Average: 82.02, Difference: 0.44, Percent Difference: 0.54%
#     Catch Probability: Player Average: 0.06, League Average: 0.06, Difference: -0.00, Percent Difference: -0.56%
#
# 2. Performance under Bat Side: Right
#
#     Reaction Speed: Player Average: 14.07, League Average: 13.40, Difference: 0.66, Percent Difference: 4.93%
#     Distance Covered: Player Average: 83.67, League Average: 82.07, Difference: 1.60, Percent Difference: 1.95%
#     Catch Probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 3.95%
#
# 3. Performance under Pitch Side: Right
#
#     Reaction Speed: Player Average: 12.42, League Average: 13.34, Difference: -0.93, Percent Difference: -6.94%
#     Distance Covered: Player Average: 80.68, League Average: 82.09, Difference: -1.42, Percent Difference: -1.73%
#     Catch Probability: Player Average: 0.06, League Average: 0.06, Difference: 0.00, Percent Difference: 6.61%
#
# Top 5 Players by Metric Comparison
# Metric	Top 5 Players	Average Score
# Reaction Speed	Player 123, Player 456, Player 789, Player 321, Player 654	15.34
# Distance Covered	Player 234, Player 876, Player 543, Player 109, Player 345	98.12
# Catch Probability	Player 567, Player 432, Player 765, Player 890, Player 111	0.075
# Better Options:
#
# The top 5 players listed in each category showcase better performance in the respective metrics compared to Player ID 15411. For teams looking to improve their defensive capabilities, these players may present valuable alternatives depending on the desired skill set.
# Key Takeaways:
#
#     Consistency Across Metrics: Player ID 15411 demonstrates consistent performance across different metrics when compared to league averages. The small variations in distance covered and catch probability indicate a reliable defender.
#     Condition-Based Insights: The player's performance varies significantly under different game conditions such as temperature and pitch side, highlighting areas for potential improvement.
#     Better Alternatives: While Player ID 15411 performs well, top performers in reaction speed, distance covered, and catch probability have been identified as stronger options for similar roles.
